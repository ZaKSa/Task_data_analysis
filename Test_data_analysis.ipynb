# %% [markdown]
# 1 Индивидуальное задание
# ---

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("/content/sample_data/Книга1.csv", sep=",", index_col=False)

df.head(70)
# Out:
#               REGION_NAME  SALARY
# 0          Алтайский край   25960
# 1        Амурская область   43156
# 2   Архангельская область   47526
# 3    Астраханская область   32166
# 4    Белгородская область   31163
# ..                    ...     ...
# 65    Саратовская область   26555
# 66       Сахалинская обл.   73261
# 67   Свердловская область   37605
# 68     Смоленская область   29566
# 69    Ставропольский край   28256
#
# [70 rows x 2 columns]

# %%
df = df[(df.REGION_NAME != 'Смоленская область') & (df.REGION_NAME !='Чувашская Республика') & (df.REGION_NAME != 'Костромская область') & (df.REGION_NAME != 'Саратовская область') ]

# %%
df
# Out:
#               REGION_NAME  SALARY
# 0          Алтайский край   25960
# 1        Амурская область   43156
# 2   Архангельская область   47526
# 3    Астраханская область   32166
# 4    Белгородская область   31163
# ..                    ...     ...
# 79    Челябинская область   34944
# 80   Чеченская Республика   26108
# 82           Чукотский АО   96930
# 83      Ямало-Ненецкий АО   86560
# 84    Ярославская область   33882
#
# [81 rows x 2 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.index+=1
df
# Out:
#               REGION_NAME  SALARY
# 1          Алтайский край   25960
# 2        Амурская область   43156
# 3   Архангельская область   47526
# 4    Астраханская область   32166
# 5    Белгородская область   31163
# ..                    ...     ...
# 77    Челябинская область   34944
# 78   Чеченская Республика   26108
# 79           Чукотский АО   96930
# 80      Ямало-Ненецкий АО   86560
# 81    Ярославская область   33882
#
# [81 rows x 2 columns]

# %%
df=df.sort_values(by='SALARY')
df
# Out:
#                         REGION_NAME  SALARY
# 49              Республика Дагестан   24550
# 18  Кабардино-Балкарская Республика   25318
# 50             Республика Ингушетия   25663
# 22  Карачаево-Черкесская Республика   25699
# 51              Республика Калмыкия   25719
# ..                              ...     ...
# 34                      Ненецкий АО   77277
# 11                        г. Москва   78946
# 80                Ямало-Ненецкий АО   86560
# 79                     Чукотский АО   96930
# 31                 Магаданская обл.  101662
#
# [81 rows x 2 columns]

# %%
df.reset_index(drop=True, inplace=True)
df.index+=1
df['SALARY'][[9,53,56]]
# Out:
# 9     26108
# 53    37857
# 56    38005
# Name: SALARY, dtype: int64

# %%
df['SALARY'].mean()
# Out:
# 39377.851851851854

# %%
df['SALARY'].median()
# Out:
# 33137.0
